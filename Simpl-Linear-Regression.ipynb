# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('height-weight.csv')

# %%
df.head()
# Out:
#    Weight  Height
# 0      50     150
# 1      52     152
# 2      54     155
# 3      55     157
# 4      57     160

# %%
#Scatter plot
plt.scatter(df['Weight'], df['Height'])
plt.title("Height - Weight Scatter Plot")
plt.xlabel("Weight")
plt.ylabel("Height")
plt.show()

# %%
#Correlation

df.corr()
# Out:
#           Weight    Height
# Weight  1.000000  0.998655
# Height  0.998655  1.000000

# %%
import seaborn as sns
sns.pairplot(df)
plt.show()

# %%
# Independent and dependent features
x = df[['Weight']] ###Independent feature should be a Dataframe or two dimensional array
y = df['Height'] ##Dependent feature should be a Series or one diemensional array

# %%
#Train test splitabs
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
x_train.shape
# Out:
# (15, 1)

# %%
##Standardization
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)

# %%
#To prevent data leakage we only use transform ins
x_test = scaler.transform
